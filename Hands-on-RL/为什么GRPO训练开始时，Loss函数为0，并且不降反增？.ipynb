# %% [markdown]
# 这个问题出现在OpenR1和trl的GRPO训练过程中，如上图所示，GRPO训练的Loss一开始为0，之后不降反增，这里面其实有两个问题要回答：
#
# - 为什么Loss初始化为0？
# - 为什么Loss的更新方向是增长方向的，不是（策略）梯度下降吗？
#
# 查阅资料后发现 OpenR1/Issue#239 给出了很好的解释：

# %% [markdown]
# ### 先来回答问题1：为什么Loss初始化为0？
