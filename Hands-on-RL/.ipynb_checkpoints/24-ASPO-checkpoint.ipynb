# %% [markdown]
# ## dual_clip +  权重反转 为核心

# %%
import  torch
import torchr.nn.functional as F

def sg(x):
    return x.detach() - x + x

# ------ASPO核心：dual-clip + 权重反转------
def aspo_loss(logits_new,logtis_old,action,advantage,eps_hard=0.2,esp_soft=0.05):
    """
    logits_new:[B,L,V] 当前策略
    logits_old:[B,L,V] 旧策略
    advantage:[B,L] 优势
    action : [B,L] token_id
    return loss
    """
    B,L,V = logits_new.shape
    tgt = action.reshape(B * L)
    
    # 1 计算ratio
    #  reduction='none'在 ASPO/GRPO/PPO 实现里，必须用 'none'，否则无法得到 逐 token 的 log π(a_t|s_t)，也就没法计算重要性权重 r_t
    logp_new = -F.cross_entropy(
        logits_new.view(-1，V),tgt, reduction='none'
    ).view(B,L)
    
    logp_old = -F.cross_entropy(
        logtis_old.view(-1,V),tgt,reduction='none'
    ).view(B,L)
    ratio = (logp_new - logp_old).exp()
    
    # 2 硬裁剪
    low,high = 1- eps_hard,1+eps_hard
    clipped = torch.clamp(ratio,low,high)
    surr1 = ratio * advantage
    surr2 = clipped * advantage
    loss_hard = -torch.min(surr1,surr2)
    
    # 3 ASPO 权重反转： 仅对dual-clip区域加软项
    big_mask = ratio > high
    small_mask = ratio < low
    dual_maks = big_mask | small_mask
    
    # 权重反转： (clip - r) 负号自动相反
    """
    ratio 过大 → r > 1+ε
    clipped = 1+ε
    clipped - ratio = (1+ε) - r   < 0      // 负号
    
    ratio 过小 → r < 1−ε
    clipped = 1−ε
    clipped - ratio = (1−ε) - r   > 0      // 正号
    """
     soft_term = sg(ratio) * eps_soft * (clipped - ratio) * advantage
    loss_total = loss_hard + torch.where(dual_mask, soft_term,torch.zeros_like(advantage))

# %%
B, L, V = 2, 10, 50257
    logits_new = torch.randn(B, L, V, requires_grad=True)
    logits_old = torch.randn(B, L, V).detach()
    action = torch.randint(0, V, (B, L))
    adv = torch.randn(B, L)

    loss = aspo_loss(logits_new, logits_old, action, adv)
    loss.backward()
    print("ASPO loss:", loss.item())

# %% [markdown]
# ##  ASPO 的三个核心模块：
# - Token Masking（硬裁剪）
# - Asymmetric Importance Sampling（正优势 token 权重翻转）
# - Soft Dual-Clipping（防极端值，保留梯度）
#
# 代码以「token-level PPO」为骨架，可直接嵌入到 GRPO / PPO 训练循环里。为简化阅读，只保留单条样本（L 个 token）的前向-损失-反向部分；
#
# batch 版本只需在外层再包一层 DataLoader 即可。

# %%
old_logp : [L]   # π_θ_old 给出的 token log-prob
new_logp : [L]   # π_θ     给出的 token log-prob
adv      : [L]   # 令牌级优势 Â_t^i（>0 正优势，<0 负优势）
eps_low  = 0.2   # 硬裁剪阈值
eps_high = 0.2
clip_high= 10.0  # 软双重裁剪上界

# %% [markdown]
# ### 计算重要性采样比 r(θ)

# %%
import torch
import torch.nn.functional as F

def compute_ratio(old_logp,new_logp):
    return torch.exp(new_logp - old_logp)

# %% [markdown]
# ### 权重生成器

# %%
ratio = torch.tensor([0.5, 0.9, 1.0, 1.1, 1.5])
hard_clip = (ratio < 0.8) | (ratio > 1.2)

# 即第 0、4 个 token 被裁掉，其余保留。
print(hard_clip)          # tensor([ True, False, False, False,  True])
print(~hard_clip)         # tensor([False,  True,  True,  True, False])
# Out:
# tensor([ True, False, False, False,  True])
# tensor([False,  True,  True,  True, False])

# %%
def aspo_weight(ratio,adv,eps_low=0.2,eps_high=0.2,clip_high=10.0):
    """
    返回最终 weight 与 mask（用于 loss 加权 & 硬裁剪掩码）
    ratio : [L]   IS 比
    adv   : [L]   优势
    """
    
    pos_mask = adv > 0
    neg_mask = adv < 0
    
    # 1 硬裁剪
    hard_clip = (ratio < (1 - eps_low)) | (ratio > (1 + eps_high))
    mask = ~hard_clip
    
    # 2 不对称权重
    weight = torch.ones_like(ratio)
    # 负优势： 不变  neg_mask为true时取ratio，否则取weight
    weight = torch.where(neg_mask,ratio,weight)
    # 正优势： 翻转 + stop-gradient
    weight = torch.where(pos_mask,(1.0/(ratio + 1e-8)).detach()* ratio,weight)
    
    # 3 软裁剪（仅正样本）
    if clip_high is not None:
        # weight > clip_high：翻转后仍太大，需封顶
        weight = torch.where(pos_mask & (weight > clip_high),clip_high + (weight - clip_high).detach(),weight)
    
    return weight,mask

# %% [markdown]
# ## 损失函数（带ASPO加权 + KL惩罚）

# %%
def aspo_loss(new_logp,old_logp,adv,beta_kl=0.1):
    ratio = compute_ratio(old_logp,new_logp)
    weight,mask = aspo_weight(ratio,adv)
    
    # 加权surrogate loss
    # 乘 mask：硬裁剪掉的 token 对 loss 贡献 =0
    surr = -weight * adv * mask  # 负号因为是最大化
    loss = surr.mean() # 平均到token 方便不同长度比较
    
    # 可选KL正则（繁殖偏离旧策略过远）
    kl = (ratio - 1 -torch.log(ratio + 1e-8)) * mask
    loss +=beta_kl * kl.mean()
    
    return loss,ratio.mean(),mask.float().mean()

# %% [markdown]
# ## 训练循环片段（单条样本）

# %%
for step, batch in enumerate(loader):
    old_logp = batch['old_logp']          # [L]
    adv      = batch['adv']               # [L]
    logits   = model(batch['input_ids'])  # -> [L, V]
    new_logp = F.log_softmax(logits, dim=-1)[range(L), batch['tokens']]

    loss, ratio_mean, clip_frac = aspo_loss(new_logp, old_logp, adv)

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
