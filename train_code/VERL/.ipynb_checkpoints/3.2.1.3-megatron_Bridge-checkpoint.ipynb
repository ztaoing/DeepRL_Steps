# %% [markdown]
# # Megatron-Bridge
# 在 Megatron-Bridge 出现之前，开发者若要将 Hugging Face 上的开源模型（如 LLaMA、Qwen 等）迁移到 Megatron 框架进行 3D 并行训练，通常需要手动编写复杂的权重转换脚本，并逐一核对模型配置，过程繁琐且极易出错。Megatron-Bridge 彻底解决了这一痛点，实现了 HF 格式与 Megatron 格式的无缝、自动互转。
