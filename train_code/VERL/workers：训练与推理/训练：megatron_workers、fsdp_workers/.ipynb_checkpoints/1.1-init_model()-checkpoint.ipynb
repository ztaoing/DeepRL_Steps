# %% [markdown]
# class ActorRolloutRefWorker(MegatronWorker, DistProfilerExtension):
# - \_\_init\_\_()
# - _build_model_optimizer()
# - _build_rollout()
# - <font color='red'>init_model()</font>
# - update_actor()
# - generate_sequences()
# - compute_ref_log_prob()
# - compute_log_prob()
# - load_checkpoint()
# - load_pretrained_model()
# - save_checkpoint()

# %%
from verl.utils.megatron_utils import (
    load_megatron_model_to_gpu,
    load_megatron_optimizer,
    offload_megatron_model_to_cpu,
    offload_megatron_optimizer,
)

from verl.workers.actor.megatron_actor import MegatronPPOActor

from verl.utils.checkpoint.megatron_checkpoint_manager import MegatronCheckpointManager

    @register(dispatch_mode=Dispatch.ONE_TO_ALL)
    def init_model(self):
        if self.config.model.get("external_lib", None) is not None:
            # This is used to import external_lib into the huggingface systems
            import importlib

            importlib.import_module(self.config.model.external_lib)

        from verl.utils.torch_dtypes import PrecisionType

        override_model_config = OmegaConf.to_container(OmegaConf.create(self.config.model.get("override_config", {})))
        if self._is_actor:
            override_transformer_config = OmegaConf.to_container(
                OmegaConf.create(self.config.actor.megatron.get("override_transformer_config", {}))
            )
            override_ddp_config = OmegaConf.to_container(
                OmegaConf.create(self.config.actor.megatron.get("override_ddp_config", {}))
            )
        elif self._is_ref:
            override_transformer_config = OmegaConf.to_container(
                OmegaConf.create(self.config.ref.megatron.get("override_transformer_config", {}))
            )
        else:
            override_transformer_config = {}
        self.param_dtype = torch.bfloat16
        log_gpu_memory_usage("Before init actor model and optimizer", logger=logger)
        self.dtype = PrecisionType.to_dtype(self.param_dtype)
        
        if self._is_actor or self._is_rollout:
            # we need the model for actor and rollout
            optim_config = self.config.actor.optim if self._is_actor else None
            (
                self.actor_module,
                self.actor_optimizer,
                self.actor_optimizer_scheduler,
                self.actor_model_config,
                self.actor_optim_config,
            ) = self._build_model_optimizer(
                model_path=self.config.model.path,
                optim_config=optim_config,
                override_model_config=override_model_config,
                override_transformer_config=override_transformer_config,
                override_ddp_config=override_ddp_config,
            )
            if self._is_offload_param:
                '''
                offload
                '''
                offload_megatron_model_to_cpu(self.actor_module)
                log_gpu_memory_usage("After offload actor params and grad during init", logger=logger)
            if self._is_offload_optimizer:
                '''
                offload
                '''
                offload_megatron_optimizer(self.actor_optimizer)
                log_gpu_memory_usage("After offload actor optimizer during init", logger=logger)

        if self._is_actor:
            actor_cfg = omega_conf_to_dataclass(self.config.actor)
            
            self.actor = MegatronPPOActor(
                config=actor_cfg,
                model_config=self.actor_model_config,
                hf_config=self.hf_config,
                tf_config=self.tf_config,
                actor_module=self.actor_module,
                actor_optimizer=self.actor_optimizer,
            )
            log_gpu_memory_usage("After MegatronPPOActor init", logger=logger)

        if self._is_rollout:
            self.rollout, self.sharding_manager = self._build_rollout(
                trust_remote_code=self.config.model.get("trust_remote_code", False)
            )
            # used for sleep/wake_up
            self.rollout.sharding_manager = self.sharding_manager
            log_gpu_memory_usage("After rollout init", logger=logger)

        if self._is_ref:
            self.ref_module, self.ref_model_config = self._build_model_optimizer(
                model_path=self.config.model.path,
                optim_config=None,
                override_model_config=override_model_config,
                override_transformer_config=override_transformer_config,
            )
            log_gpu_memory_usage("After ref model init", logger=logger)
            self.ref_policy = MegatronPPOActor(
                config=self.config.ref,
                model_config=self.ref_model_config,
                hf_config=self.hf_config,
                tf_config=self.tf_config,
                actor_module=self.ref_module,
                actor_optimizer=None,
            )
            if self._ref_is_offload_param:
                '''
                offload
                '''
                offload_megatron_model_to_cpu(self.ref_module)
                log_gpu_memory_usage("After offload ref params during init", logger=logger)

        if self._is_actor:
            self.flops_counter = FlopsCounter(self.actor_model_config)
            
            self.checkpoint_mananager = MegatronCheckpointManager(
                config=self.config,
                checkpoint_config=self.config.actor.checkpoint,
                model_config=self.actor_model_config,
                transformer_config=self.tf_config,
                role="actor",
                model=self.actor_module,
                arch=self.architectures[0],
                hf_config=self.hf_config,
                param_dtype=self.param_dtype,
                share_embeddings_and_output_weights=self.share_embeddings_and_output_weights,
                processing_class=self.processor if self.processor is not None else self.tokenizer,
                optimizer=self.actor_optimizer,
                optimizer_scheduler=self.actor_optimizer_scheduler,
                use_distributed_optimizer=self.config.actor.megatron.use_distributed_optimizer,
                use_checkpoint_opt_param_scheduler=self.config.actor.optim.use_checkpoint_opt_param_scheduler,
                bridge=self.bridge,
                use_dist_checkpointing=self.config.actor.megatron.use_dist_checkpointing,
            )
        get_torch_device().empty_cache()
        log_gpu_memory_usage("After init_model finish", logger=logger)

# %% [markdown]
# ## 1. 核心魔法：@register(dispatch_mode=Dispatch.ONE_TO_ALL)
# <font color='red'>在传统的分布式编程中，开发者往往需要手动编写繁琐的“数据分发 -> 节点计算 -> 结果收集”的代码。VeRL 框架通过 @register 装饰器实现了一种声明式分布式编程。</font>
# - 声明式接口：这个装饰器本质上是为 init_model 函数打上了一个特殊的“标签”（<font color='red'>在源码中表现为给函数添加了 MAGIC_ATTR 属性</font>）。<font color='green'>它告诉底层的分布式框架（如基于 Ray 实现的 WorkerGroup）：当调用这个函数时，请按照我指定的规则来处理分布式通信。</font>
#
# - Dispatch.ONE_TO_ALL 模式：这是该装饰器最关键的参数。它的含义是 “一对多分发”。
#     - 执行流程：当 Driver（驱动端/主节点）调用被该装饰器修饰的 init_model 方法时，框架会自动将相同的调用指令分发给资源池中所有的 Worker 进程（即分布式训练集群中的每一张显卡对应的进程）。
#     - <font color='red'>开发者的无感体验</font>：你只需要像在写单机程序一样写 init_model 内部的逻辑，完全不需要关心底层的进程组（Process Group）是如何建立的，也不需要手动去写 torch.distributed.new_group 或 Ray 的远程调用。<font color='red'>框架会在运行时根据这个装饰器，动态生成包装函数，自动完成“向所有节点下发初始化指令”的动作。</font>
#
# ## 2. 函数内部逻辑：init_model 的具体工作
# init_model 函数本身是一个高度模块化的模型工厂，<font color='red'>它根据当前 Worker 承担的角色（Actor、Rollout 或 Reference），按需构建和加载模型。</font>
#
# - 动态导入与配置解析：
#
# 首先检查是否有外部库（external_lib）需要导入，这通常用于兼容 Hugging Face 生态中的一些特殊模型。
# <font color='red'>利用 OmegaConf 解析并合并用户传入的模型配置（override_model_config）和 Megatron 的底层 Transformer 配置。</font>
#
# - 基于角色的模型构建（Role-based Building）：
#
# 函数内部通过 self._is_actor、self._is_rollout、self._is_ref 等标志位，<font color='red'>判断当前进程需要初始化哪些组件：</font>
#    - <font color='red'>Actor（策略模型）</font>：如果是 Actor 角色，会调用 _build_model_optimizer 构建完整的模型、优化器（Optimizer）以及学习率调度器。同时，它还支持将模型参数或优化器状态卸载到 CPU（offload_megatron_model_to_cpu），以节省宝贵的显存。最后，将构建好的模块封装进 MegatronPPOActor 中。
#
#    - <font color='red'>Rollout（推理/采样引擎）</font>：如果是 Rollout 角色（通常用于生成训练数据），它会调用 _build_rollout 来构建推理引擎（在 VeRL 中通常是 vLLM），并建立与 Actor 模型之间的权重同步管理器（sharding_manager）。
#
#    - <font color='red'>Reference（参考模型）</font>：如果是 Reference 角色（用于计算 KL 散度等约束），它会加载模型参数，但不需要构建优化器（actor_optimizer=None），同样支持参数卸载以节省内存。
#
# - 辅助组件与资源清理：
#     - <font color='red'>如果是 Actor，还会初始化 Flops 计数器（FlopsCounter）用于性能评估，以及 Megatron 的检查点管理器（MegatronCheckpointManager）用于模型的保存与恢复。</font>
#     - 函数最后调用 get_torch_device().empty_cache() 清理显存缓存，并记录初始化完成后的 GPU 显存使用情况。
#
# 总结来说，这段代码展示了现代大模型训练框架的优雅架构：
# - 外层通过 @register 装饰器将复杂的分布式通信细节彻底解耦，
# - 内层通过清晰的角色判断逻辑，灵活地组装出支持 Megatron-LM 极致并行化能力的大模型训练组件。

# %% [markdown]
# # MegatronPPOActor
# - from verl.workers.actor.megatron_actor import MegatronPPOActor
#
# class MegatronPPOActor(BasePPOActor):
# - <font color='red'>def \_\_init\_\_</font>
# - def _validate_config
# - def compute_log_prob
# - def make_minibatch_iterator
# - def forward_backward_batch
# - def update_policy

# %%
from megatron.core.distributed import finalize_model_grads
from megatron.core.optimizer import DistributedOptimizer

class MegatronPPOActor(BasePPOActor):
    
    def __init__(
        self,
        config,
        model_config,
        hf_config,
        tf_config,
        actor_module: nn.ModuleList,
        actor_optimizer: DistributedOptimizer,
    ):
        """MeagtronPPOActor class. This class implements the simple PPO logics when the model is built with Megatron.

        Args:
            config (OmegaConf): the basic config that contains the hyper-parameters of PPO Actor. It must contain

                ``ppo_micro_batch_size_per_gpu``: micro batch size when updating ppo.

                ``ppo_mini_batch_size``: minibatch size when updating ppo using the batch data.

                ``ppo_epochs``: number of epochs to update the actor using the batch data.

                ``shuffle``: whether to shuffle the data after each ppo epoch.

                ``clip_ratio``: clip ratio of the ppo algorithm. See https://arxiv.org/abs/1707.06347.

                ``entropy_coeff``: entropy coefficient of the PPO loss. See https://arxiv.org/abs/1707.06347.
            model_config (OmegaConf): model configuration. It must contains ``model_config.vocab_size`` and
                ``model_config.hidden_size``
            hf_config (PretrainedConfig): huggingface config
            tf_config (TransformerConfig): mcore transformer config
            actor_module (nn.ModuleList): actor module is a ModuleList that contains a list of nn.Module in this
                pp stage.
                each nn.Module in this rank holds a vpp module chunk. See https://arxiv.org/pdf/2104.04473.pdf for
                more details.
                The actor module has some constraints to follow in order to use the updating logics implemented here

                1. It must implement unpad_input before any computation and pad_input after all the computation.
                Remove padding is an
                optimization that removes the padding tokens. See unpad_input and pad_input function in flash-attn
                (https://github.com/Dao-AILab/flash-attention/blob/main/flash_attn/bert_padding.py).

                2. Each pp stage must return the hidden state with the same shape [total_nnz, 1, hidden_size],
                where total_nnz is the number of valid tokens in this batch. If sequence parallel is enabled, the size
                of the hidden state is [total_nnz // tp, 1, hidden_size].
            actor_optimizer (DistributedOptimizer): currently, we only support DistributedOptimizer in Megatron.
                It implements
                zero1 optimizer that shards the optimizer state across dp ranks.

        >>> from megatron.training import get_model
        >>> from megatron.optimizer import get_megatron_optimizer
        >>> actor_module = get_model(megatron_actor_model_provider, wrap_with_ddp=True)
        >>> actor_module = nn.ModuleList(actor_module)
        >>> actor_optimizer = get_megatron_optimizer(actor_module)
        >>> actor = MegatronPPOActor(config=config,
        >>>                          model_config=actor_model_config,
        >>>                          hf_config=hf_config,
        >>>                          tf_config=tf_config,
        >>>                          actor_module=actor_module,
        >>>                          actor_optimizer=actor_optimizer)
        """
        super().__init__(config)
        self._validate_config(config)
        self.model_config = model_config
        self.hf_config = hf_config
        self.tf_config = tf_config
        self.actor_module = actor_module
        '''
        代码中明确标注了 actor_optimizer 为 DistributedOptimizer，
        强调了该框架对 Megatron 分布式优化器的强依赖。
        
        '''
        self.actor_optimizer: DistributedOptimizer = actor_optimizer
        self.prof = Profiler(self.config.profile)
        self.use_fused_kernels = self.config.get("use_fused_kernels", False)
        if self.use_fused_kernels:
            from verl.models.mcore.model_forward_fused import patch_fused_forward

            for model in self.actor_module:
                patch_fused_forward(model)

        self.optimizer_step_args = OmegaConf.create(
            {
                "skip_grad": None,
                "overlap_dp_param_comm": False,
                "overlap_dp_grad_comm": False,
                "gradient_accumulation_steps": 1,
                "sequence_parallel": self.tf_config.sequence_parallel,
                "DDP_impl": "local",
                "layernorm_allreduce_bucket_threshold": 0,
                "pipeline_model_parallel_split_rank": None,
                "reduce_grads_use_alltoall": False,
            }
        )

        config = get_model_config(self.actor_module[0])
        print(config)
        config.finalize_model_grads_func = finalize_model_grads

# %% [markdown]
# ## 1. 函数签名与参数定义
# - 该方法接收 6 个核心参数，定义了模型配置、硬件配置以及计算组件。
#
# | 参数名 | 类型 | 说明 |
# | :--- | :--- | :--- |
# | `config` | `OmegaConf` | <font color='red'>PPO 超参数配置</font>。包含训练策略所需的核心超参数，如 `clip_ratio` (PPO 剪切系数)、`entropy_coeff` (熵系数)、`ppo_micro_batch_size_per_gpu` (微批次大小) 等。 |
# | `model_config` | `OmegaConf` | <font color='red'>模型结构配置</font>。必须包含 `vocab_size` (词表大小) 和 `hidden_size` (隐藏层维度) 等信息，用于内部计算或校验。 |
# | `hf_config` | `PretrainedConfig` | <font color='red'>Hugging Face 模型的配置对象</font>。用于兼容 Hugging Face 生态，方便加载预训练权重或进行模型转换。 |
# | `tf_config` | `TransformerConfig` | <font color='red'>Megatron Transformer 配置</font>。定义了并行策略（如 Tensor Parallelism `tp`、Pipeline Parallelism `pp`）、Sequence Parallelism 等分布式训练参数。 |
# | `actor_module` | `nn.ModuleList` | <font color='red'>Actor 模型模块</font>。这是一个包含当前 Pipeline Parallel (PP) 阶段所有模型分片（VPP Chunk）的列表。每个分片是一个 `nn.Module`。 |
# | `actor_optimizer` | `DistributedOptimizer` | <font color='red'>分布式优化器</font>。通常为 Megatron 实现的 `DistributedOptimizer`，支持 ZeRO-1 优化，将优化器状态在数据并行（DP）组内进行分片存储。 |
#
# ## 2. 核心逻辑与初始化流程
# 在 __init__ 方法内部，代码执行了以下关键步骤：
# ### A. 基础初始化与配置校验
# - 父类继承：调用 super().__init__(config) 初始化父类。
# - 配置验证：调用 self._validate_config(config) 对传入的 PPO 超参数进行合法性检查。
# - 属性赋值：将 model_config, hf_config, tf_config 等配置保存为实例属性。
#
# ### B. 模块与优化器绑定
# - <font color='red'>将传入的 actor_module（模型）和 actor_optimizer（优化器）绑定到当前实例。</font>
# - 类型注解：代码中明确标注了 actor_optimizer 为 DistributedOptimizer，强调了该框架对 Megatron 分布式优化器的强依赖。
#
# ### C. <font color='red'>性能分析与融合算子（Fused Kernels）</font>
# - Profiler：初始化 Profiler 对象，用于监控训练过程中的性能瓶颈。
# - 融合算子注入：
#     - 检查配置 use_fused_kernels。
#     - 如果启用，从 verl.models.mcore.model_forward_fused 导入 patch_fused_forward。
#     - Patch 机制：遍历 actor_module 中的每一个模型分片，动态替换其前向传播（Forward）逻辑。这通常用于注入特定的 CUDA 融合算子（如 FlashAttention），以提升计算效率。
#
# ### D. 优化器参数配置
# - 创建 optimizer_step_args 字典，预设了 Megatron 优化器步进（Optimizer Step）所需的各种标志位：
#     - sequence_parallel: 根据 tf_config 启用序列并行。
#     - gradient_accumulation_steps: 梯度累积步数，设置为 1（意味着在 Actor 的单步更新中不进行累积，由外部 PPO 循环控制）。
#
# ### E. 模型配置微调 (关键 Bug/待补全点)
# 代码最后部分存在一个明显的语法错误或未完成的代码片段：
# - config = get_model_config(self.actor_module[0]): 获取 Megatron 模型的内部配置对象。
# - config.finalize_model_grads_func = finalize_model_grads<time_location>: 这里试图将梯度归约完成函数替换为自定义的 finalize_model_grads，但代码被 <time_location> 标签截断。
# - 注意：这里的 <time_location> 显然是一个占位符或错误信息（可能源于代码生成或日志注入），导致语法不完整。正确的代码应该是将 finalize_model_grads 函数赋值给该属性，用于在反向传播结束时处理模型梯度（例如处理 Pipeline Parallel 的梯度归约）。
#
# ## 3. 设计模式与架构特点
# ### Megatron 深度集成：
# <font color='red'>该类的设计完全基于 Megatron-LM 的并行范式。</font>
#
# - ModuleList 结构：actor_module 是一个 ModuleList，<font color='red'>这对应了 Megatron 中将一个大模型切分成多个 Virtual Pipeline Parallel (VPP) Chunk 的机制。</font>
#
# - DistributedOptimizer 依赖：<font color='red'>强制要求使用 Megatron 的优化器，以利用其 ZeRO 优化和通信重叠技术，这对于训练千亿参数大模型是必须的。</font>
#
# ### 混合精度与配置管理：
# - 使用 OmegaConf 管理复杂的嵌套配置，结合 Hugging Face (hf_config) 和 Megatron (tf_config) 两套配置体系，实现了灵活的模型加载和训练控制。
# ### 可插拔的优化策略：
# - 通过 use_fused_kernels 机制，允许在不修改模型源码的情况下，动态注入高性能算子，体现了框架的扩展性。
#
# 总结：这段代码是连接强化学习算法（PPO）与底层大规模并行训练框架（Megatron）的桥梁。它负责将 PPO 的超参数、模型结构、并行策略以及优化器组装在一起，并为后续的策略更新（Actor Update）做好准备。代码末尾的语法错误需要修复以确保梯度处理逻辑正常工作。

# %% [markdown]
# # DistributedOptimizer
# - from megatron.core.optimizer import DistributedOptimizer
#
# <font color='red'>内容详见megatron目录</font>
