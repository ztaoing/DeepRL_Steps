# %% [markdown]
# - 简单来说：计算权重梯度是为了“更新当前层”，而计算输入梯度是为了“通知上一层”。
# - 如果没有输入梯度，反向传播的链条就会在当前层断裂，导致前面的所有层都无法学习。
#
# 下面我通过三个层面来详细解释：

# %%
from IPython.display import Image

# %%
Image(filename='./grad1.PNG')

# %%
Image(filename='./grad2.PNG')

# %% [markdown]
# # 根据损失来更新第 L 层的权重矩阵 W_L
# - 这个公式是深度学习中反向传播（Backpropagation）算法的核心基石。
# - <font color='red'>它描述了在训练神经网络时，如何根据最终的损失（Loss）来更新第 L 层的权重矩阵 W_L</font>

# %%
Image(filename='./gs1.PNG')

# %%
Image(filename='./gs2.PNG')

# %%
Image(filename='./gs3.PNG')

# %% [markdown]
# # 当前层计算梯度时“不需要下一层完整输入”

# %%
Image(filename='./gs4.PNG')

# %%
Image(filename='./gs5.PNG')

# %%
Image(filename='./gs6.PNG')
