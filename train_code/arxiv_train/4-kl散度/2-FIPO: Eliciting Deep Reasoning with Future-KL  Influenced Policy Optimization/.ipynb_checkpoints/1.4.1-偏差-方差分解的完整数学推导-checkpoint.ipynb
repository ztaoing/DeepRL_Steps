# %% [markdown]
# # 问题设定

# %%
from IPython.display import Image

# %%
Image(filename='./Image/pf_1.png')

# %% [markdown]
# # 推导过程

# %%
Image(filename='./Image/pf_2.png')

# %%
Image(filename='./Image/pf_3.png')
