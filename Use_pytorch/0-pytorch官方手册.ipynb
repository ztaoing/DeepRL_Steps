# %% [markdown]
# # 主文档站
# - https://pytorch.org/docs/stable/index.html

# %% [markdown]
# | 内容                          | 链接                                             |
# | :-------------------------- | :--------------------------------------------- |
# | **torch 核心 API**            | <https://pytorch.org/docs/stable/torch.html>   |
# | **torch.nn (神经网络)**         | <https://pytorch.org/docs/stable/nn.html>      |
# | **torch.optim (优化器)**       | <https://pytorch.org/docs/stable/optim.html>   |
# | **torch.utils.data (数据加载)** | <https://pytorch.org/docs/stable/data.html>    |
# | **Tensor 操作**               | <https://pytorch.org/docs/stable/tensors.html> |
# | **CUDA 支持**                 | <https://pytorch.org/docs/stable/cuda.html>    |

# %% [markdown]
# - PyTorch 中文文档: https://pytorch.apachecn.org/ （社区翻译，可能滞后）
