# %% [markdown]
# trl/
# ├── trainer/           ├── models/           # 模型封装器和架构支持
# ├── data_utils.py     # 数据处理和格式化工具
# ├── rewards/          # 奖励模型实现
# ├── scripts/          # 命令行界面脚本
# ├── experimental/     # 前沿实验性功能
# ├── cli.py           # 主命令行界面
# └── core.py          # 核心工具和函数
