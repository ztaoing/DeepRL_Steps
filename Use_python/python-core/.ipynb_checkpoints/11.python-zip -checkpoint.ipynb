# %% [markdown]
# https://www.cnblogs.com/tian777/p/17314318.html

# %%
# 传入一个参数

grid = [[3,0,8,4],[2,4,5,7],[9,2,6,3],[0,3,1,0]]
print(list(zip(grid)))     
# [([3, 0, 8, 4],), ([2, 4, 5, 7],), ([9, 2, 6, 3],), ([0, 3, 1, 0],)]


print(list(zip(*grid)))
# [(3, 2, 9, 0), (0, 4, 2, 3), (8, 5, 6, 1), (4, 7, 3, 0)]
# Out:
# [([3, 0, 8, 4],), ([2, 4, 5, 7],), ([9, 2, 6, 3],), ([0, 3, 1, 0],)]
# [(3, 2, 9, 0), (0, 4, 2, 3), (8, 5, 6, 1), (4, 7, 3, 0)]

# %%
#输入数据不等长时

grid = [[3,0,8,4],[2,4,5,7],[9,2,6,3],[0,3,1]]
print(list(zip(grid)))    
[([3, 0, 8, 4],), ([2, 4, 5, 7],), ([9, 2, 6, 3],), ([0, 3, 1],)]

grid = [[3,0,8,4],[2,4,5,7],[9,2,6,3],[0,3,1]]
print(list(zip(*grid)))
# [(3, 2, 9, 0), (0, 4, 2, 3), (8, 5, 6, 1)]

# %%
# 输入数据不等长
# 输出取决于最短的数据

x = [1, 2, 3]
y = [4, 5, 6, 11]
z = [7, 8, 9, 10]
 
xyz = zip(x, y, z)
print xyz运行的结果是：
 
[(1, 4, 7), (2, 5, 8), (3, 6, 9)]

1 11
2 12
3 13

# %%
# 处理不等长数据可以内置zip_longest代替

# 使用itertools包中的zip_longest，使用方法如下：

from itertools import zip_longest
a = [1,2,3,4,5,6]
b = [11,12,13]

for i,j in zip_longest(a,b):
	print(i,j)
# Out:
# 1 11
# 2 12
# 3 13
# 4 None
# 5 None
# 6 None
