# %% [markdown]
# ### literal_eval() 函数：会判断需要计算的内容计算后是不是合法的python类型，如果是则进行运算，否则就不进行运算。
#
# 从而避免了意外风险的执行系统命令

# %%
import ast

str1="('name','beike','home','beijing')"
str2="[1,2,3,4,5]"
evalstr1=eval(str1)
print(type(str1))
print(evalstr1)
print(type(evalstr1))

aststr1=ast.literal_eval(str1)

aststr2=ast.literal_eval(str2)
print(aststr1)
print(aststr2)
# Out:
# <class 'str'>
# ('name', 'beike', 'home', 'beijing')
# <class 'tuple'>
# ('name', 'beike', 'home', 'beijing')
# [1, 2, 3, 4, 5]

# %%
import os 


ROOT=os.getcwd()
print(os.getcwd())
print(os.listdir(ROOT))

print(eval("os.listdir(ROOT)"))

import ast
print(ast.literal_eval("os.getcwd()"))
# Out:
# /Users/tao/gittao/DeepRL_Steps/Use_python/python-core
# ['7.python-print函数 .ipynb', '6.python-内置函数 .ipynb', '10.python-深拷贝和浅拷贝 .ipynb', '5.python-set .ipynb', '18.python-描述器 .ipynb', '21.python异常处理和断言 .ipynb', '2.python-dict .ipynb', '15.面向对象和super .ipynb', '1、python-list.ipynb', '22.函数eval和ast.literal_eval .ipynb', '8.python-闭包和装饰器 .ipynb', '13.python-yield和yield from.ipynb', '4.python-迭代器生成器 .ipynb', '16.python-单例模式.ipynb', '20.python@property .ipynb', '.ipynb_checkpoints', '12.python-类型提示 .ipynb', '3.python-str .ipynb', '11.python-zip .ipynb', '19.实例方法,类方法,静态方法 .ipynb', '9.python-下划线 .ipynb', '14.python-lambda函数 .ipynb', '17.python-魔术方法.ipynb']
# ['7.python-print函数 .ipynb', '6.python-内置函数 .ipynb', '10.python-深拷贝和浅拷贝 .ipynb', '5.python-set .ipynb', '18.python-描述器 .ipynb', '21.python异常处理和断言 .ipynb', '2.python-dict .ipynb', '15.面向对象和super .ipynb', '1、python-list.ipynb', '22.函数eval和ast.literal_eval .ipynb', '8.python-闭包和装饰器 .ipynb', '13.python-yield和yield from.ipynb', '4.python-迭代器生成器 .ipynb', '16.python-单例模式.ipynb', '20.python@property .ipynb', '.ipynb_checkpoints', '12.python-类型提示 .ipynb', '3.python-str .ipynb', '11.python-zip .ipynb', '19.实例方法,类方法,静态方法 .ipynb', '9.python-下划线 .ipynb', '14.python-lambda函数 .ipynb', '17.python-魔术方法.ipynb']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 11
#       8 print(eval("os.listdir(ROOT)"))
#      10 import ast
# ---> 11 print(ast.literal_eval("os.getcwd()"))
#
# File /opt/anaconda3/envs/gym3.10.10/lib/python3.10/ast.py:110, in literal_eval(node_or_string)
#     108                 return left - right
#     109     return _convert_signed_num(node)
# --> 110 return _convert(node_or_string)
#
# File /opt/anaconda3/envs/gym3.10.10/lib/python3.10/ast.py:109, in literal_eval.<locals>._convert(node)
#     107         else:
#     108             return left - right
# --> 109 return _convert_signed_num(node)
#
# File /opt/anaconda3/envs/gym3.10.10/lib/python3.10/ast.py:83, in literal_eval.<locals>._convert_signed_num(node)
#      81     else:
#      82         return - operand
# ---> 83 return _convert_num(node)
#
# File /opt/anaconda3/envs/gym3.10.10/lib/python3.10/ast.py:74, in literal_eval.<locals>._convert_num(node)
#      72 def _convert_num(node):
#      73     if not isinstance(node, Constant) or type(node.value) not in (int, float, complex):
# ---> 74         _raise_malformed_node(node)
#      75     return node.value
#
# File /opt/anaconda3/envs/gym3.10.10/lib/python3.10/ast.py:71, in literal_eval.<locals>._raise_malformed_node(node)
#      69 if lno := getattr(node, 'lineno', None):
#      70     msg += f' on line {lno}'
# ---> 71 raise ValueError(msg + f': {node!r}')
#
# ValueError: malformed node or string on line 1: <ast.Call object at 0x10f9cb280>
