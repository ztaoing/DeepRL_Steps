# %% [markdown]
# | 特性 | `[::-1]` (切片反转) | `reversed()` (内置函数) |
# | :--- | :--- | :--- |
# | 返回值 | 返回一个新的列表（副本）。 | 返回一个迭代器（视图）。 |
# | 内存占用 | O(N)。会复制一份数据，占用双倍内存。 | O(1)。不复制数据，只记录反向遍历的逻辑，极度省内存。 |
# | 执行速度 | 创建副本需要时间，但在小数据上很快。 | 创建极快，但遍历时才逐个计算。 |
# | 适用场景 | 需要多次访问反转后的数据，或者需要将其转换为 Tensor/数组时。 | 仅需遍历一次数据，且数据量极大时。 |
