# %% [markdown]
# 标准库地址： https://docs.python.org/zh-cn/3.13/library/index.html

# %%
from IPython.display import Image

# %%
Image(filename='./Image/pb_1.png')

# %%
Image(filename='./Image/pb_2.png')

# %%
Image(filename='./Image/pb_3.png')

# %%
Image(filename='./Image/pb_4.png')

# %%
Image(filename='./Image/pb_5.png')

# %%
Image(filename='./Image/pb_6.png')

# %%
Image(filename='./Image/pb_7.png')

# %%
Image(filename='./Image/pb_8.png')

# %%
Image(filename='./Image/pb_9.png')

# %%
Image(filename='./Image/pb_10.png')

# %%
Image(filename='./Image/pb_11.png')

# %%
Image(filename='./Image/pb_12.png')

# %%
Image(filename='./Image/pb_13.png')

# %%
Image(filename='./Image/pb_14.png')

# %%
Image(filename='./Image/pb_15.png')

# %%
Image(filename='./Image/pb_16.png')

# %%
Image(filename='./Image/pb_17.png')

# %%
Image(filename='./Image/pb_18.png')

# %%
Image(filename='./Image/pb_19.png')

# %%
Image(filename='./Image/pb_20.png')

# %%
Image(filename='./Image/pb_21.png')

# %%
Image(filename='./Image/pb_22.png')

# %%
Image(filename='./Image/pb_23.png')
