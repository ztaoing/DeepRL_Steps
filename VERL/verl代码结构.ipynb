# %%
verl/
├── verl/                          # 核心源码包
│   ├── __init__.py
│   ├── core/                      # 核心组件
│   │   ├── __init__.py
│   │   ├── data.py                # DataProto 数据协议
│   │   ├── config.py              # 配置管理
│   │   └── torch_module.py        # PyTorch 模块工具
│   ├── models/                    # 模型定义
│   │   ├── __init__.py
│   │   ├── llm.py                 # LLM 模型封装
│   │   └── transformers/          # Transformers 兼容层
│   ├── protocol.py                # DataProto 实现 ⭐
│   ├── single_controller/         # 单控制器架构 ⭐
│   │   ├── __init__.py
│   │   ├── base.py                # Worker 基类
│   │   ├── worker.py              # Worker 实现
│   │   └── ray/                   # Ray 分布式后端
│   │       ├── __init__.py
│   │       ├── base.py            # RayWorkerGroup
│   │       └── resource_pool.py   # 资源池管理
│   ├── multi_controller/          # 多控制器（Worker 内部）
│   │   └── __init__.py
│   ├── trainer/                   # 训练器
│   │   ├── __init__.py
│   │   ├── main_ppo.py            # PPO 入口
│   │   ├── main_grpo.py           # GRPO 入口 ⭐
│   │   ├── config/                # 配置文件
│   │   │   ├── ppo_trainer.yaml
│   │   │   └── grpo_trainer.yaml
│   │   └── ray_trainer.py         # Ray 训练器基类
│   ├── workers/                   # Worker 实现 ⭐
│   │   ├── __init__.py
│   │   ├── actor_rollout_worker.py    # Actor + Rollout
│   │   ├── critic_worker.py           # Critic (PPO)
│   │   ├── reward_model_worker.py     # 奖励模型
│   │   ├── ref_worker.py              # 参考模型
│   │   ├── sharding_manager/          # 分片管理
│   │   │   ├── __init__.py
│   │   │   ├── fsdp_vllm.py           # FSDP <-> vLLM
│   │   │   ├── fsdp_sglang.py         # FSDP <-> SGLang
│   │   │   └── megatron_vllm.py       # Megatron <-> vLLM
│   │   └── megatron_workers.py        # Megatron 后端
│   ├── utils/                     # 工具函数
│   │   ├── __init__.py
│   │   ├── debug.py
│   │   ├── fsdp_utils.py
│   │   ├── megatron_utils.py
│   │   └── torch_functional.py
│   ├── algorithms/                # 算法实现
│   │   ├── __init__.py
│   │   ├── ppo.py                 # PPO 算法
│   │   ├── grpo.py                # GRPO 算法 ⭐
│   │   └── gae.py                 # GAE 计算
│   ├── rollout/                   # 推理引擎接口
│   │   ├── __init__.py
│   │   ├── vllm_engine.py         # vLLM 引擎
│   │   ├── sglang_engine.py       # SGLang 引擎
│   │   └── async_server.py        # 异步服务
│   └── dataset/                   # 数据处理
│       ├── __init__.py
│       └── rl_dataset.py
├── examples/                      # 示例
│   ├── data_preprocess/           # 数据预处理脚本
│   ├── ppo/                       # PPO 示例
│   └── grpo/                      # GRPO 示例
├── tests/                         # 测试
├── docs/                          # 文档
└── scripts/                       # 安装脚本
    └── install_vllm_sglang_mcore.sh
